# %% [markdown]
# # 📌 1: Discreate Random Variable
# ## A Random variable that takes on a countable number of distinct values.
# Ex --> rolling a dice (we only get 1, 2,3,4,5,6)
#
#
# # 📌 2: Continuous Random Variable
# ## A Random variable that can take on any value within a given range on interval.
# Ex --> counting the length of people those attend a fear ( we get value between a range)
