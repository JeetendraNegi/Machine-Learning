# %% [markdown]
# Probability distributions describe how the probabilities of different outcomes are distributed over the sample space of a random variable.

# %% [markdown]
# 📌 Probability Distribution Function (PDF) and Its Types
# 🔹 Definition of Probability Distribution Function
# A Probability Distribution Function (PDF) describes how probabilities are distributed over the possible values of a random variable. It provides the likelihood of different outcomes occurring in a statistical experiment.
#
# A probability distribution can be discrete or continuous depending on the type of random variable.
#
# 🔹 Types of Probability Distributions
# Probability distributions are broadly classified into:
#
# Discrete Probability Distributions (for discrete random variables)
#
# Continuous Probability Distributions (for continuous random variables)
#
# 📌 1️⃣ Discrete Probability Distributions
# A discrete probability distribution applies to scenarios where the random variable takes a finite or countable set of values.
#
# ✅ Examples of Discrete Distributions
# Distribution	Description	Formula
# Bernoulli Distribution	Models a single trial with two outcomes: Success (1) or Failure (0)
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# =
# 𝑝
# 𝑥
# (
# 1
# −
# 𝑝
# )
# 1
# −
# 𝑥
# P(X=x)=p
# x
#  (1−p)
# 1−x
#
# Binomial Distribution	Models the number of successes in n independent trials
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# (
# 𝑛
# 𝑘
# )
# 𝑝
# 𝑘
# (
# 1
# −
# 𝑝
# )
# 𝑛
# −
# 𝑘
# P(X=k)=(
# k
# n
# ​
#  )p
# k
#  (1−p)
# n−k
#
# Poisson Distribution	Models the number of events occurring in a fixed interval
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# 𝜆
# 𝑘
# 𝑒
# −
# 𝜆
# 𝑘
# !
# P(X=k)=
# k!
# λ
# k
#  e
# −λ
#
# ​
#
# 📌 2️⃣ Continuous Probability Distributions
# A continuous probability distribution applies to a scenario where the random variable takes an infinite number of possible values within a given range.
#
# The Probability Density Function (PDF) is used to describe the probability distribution of continuous random variables.
#
# ✅ Examples of Continuous Distributions
# Distribution	Description	PDF Formula
# Normal (Gaussian) Distribution	Models real-world phenomena (e.g., height, weight, test scores)
# 𝑓
# (
# 𝑥
# )
# =
# 1
# 𝜎
# 2
# 𝜋
# 𝑒
# −
# (
# 𝑥
# −
# 𝜇
# )
# 2
# 2
# 𝜎
# 2
# f(x)=
# σ
# 2π
# ​
#
# 1
# ​
#  e
# −
# 2σ
# 2
#
# (x−μ)
# 2
#
# ​
#
#
# Exponential Distribution	Models waiting time between independent events
# 𝑓
# (
# 𝑥
# )
# =
# 𝜆
# 𝑒
# −
# 𝜆
# 𝑥
# f(x)=λe
# −λx
#
# Uniform Distribution	All outcomes are equally likely within a range
# 𝑓
# (
# 𝑥
# )
# =
# 1
# 𝑏
# −
# 𝑎
# ,
# 𝑎
# ≤
# 𝑥
# ≤
# 𝑏
# f(x)=
# b−a
# 1
# ​
#  ,a≤x≤b
# 📌 Summary Table
# Type	Distribution	Use Case
# Discrete	Bernoulli	Single success/failure event
# Discrete	Binomial	Multiple independent trials
# Discrete	Poisson	Number of events in a fixed interval
# Continuous	Normal	Real-world continuous data
# Continuous	Exponential	Time between events
# Continuous	Uniform	Equal probability for all values
